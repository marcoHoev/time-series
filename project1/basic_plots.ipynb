# %%
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import STL
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os

temp = os.getcwd()
print(f'Current working directory: {temp}')
if '/project1' in temp:
    temp = temp.replace('/project1', '')
    os.chdir(temp)
    print(f'Switched to: {temp}')
# Out:
# Current working directory: /Users/timmaier/Dropbox/uni/master/semester4/TSA/Research Project/time-series/project1
# Switched to: /Users/timmaier/Dropbox/uni/master/semester4/TSA/Research Project/time-series

# %%
data = pd.read_excel('data/QualidadeARO3.xlsx')
data = data.drop(columns='Ihavo')

# %%
plt.figure(figsize=(20,20))
for idx, o2levels in enumerate(data.columns):
    plt.subplot(3, 3, idx+1)
    plt.plot(data.index, data[o2levels])
    plt.gca().set_title(o2levels)
plt.show()

# %%
plt.figure(figsize=(20,20))
for idx, o2levels in enumerate(data.columns):
    #plt.subplot(3, 3, idx+1)
    plot_acf(data[o2levels], lags=72, title=o2levels)
plt.show()

# %%
data.columns
# Out:
# Index(['Antas-Espinho', 'Entrecampos', 'Estarreja', 'Laranjeiro-Almada',
#        'Mem-Martins', 'Paio-Pires', 'Restelo', 'Sobreiras-Porto',
#        'VNTelha-Maia'],
#       dtype='object')
